# %% [markdown]
# Obtener los datos

# %%
import pandas as pd


data = pd.read_csv("C:\\Users\\Aula E-2\\Downloads\\abalone\\abalone.data", header = None)
data.columns = ['SEX', 'LENGTH', 'DIAMETER', 'HEIGHT', 'FULL_W',
               'SHUCKED_W', 'VISERAL_W', 'SHELL_W', 'RINGS']
data['SEX'] = data['SEX'].map({
    'M':1,
    'F':2,
    'I':3
})
data.sample(5)
# Out:
#       SEX  LENGTH  DIAMETER  HEIGHT  FULL_W  SHUCKED_W  VISERAL_W  SHELL_W  \
# 2307    2   0.465     0.375   0.135  0.6000     0.2225     0.1290    0.230
# 720     3   0.160     0.110   0.025  0.0180     0.0065     0.0055    0.005
# 1107    3   0.510     0.380   0.115  0.5155     0.2150     0.1135    0.166
# 3585    1   0.625     0.485   0.160  1.2135     0.6310     0.2235    0.302
# 15      1   0.500     0.400   0.130  0.6645     0.2580     0.1330    0.240
#
#       RINGS
# 2307     16
# 720       3
# 1107      8
# 3585      9
# 15       12

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4177 entries, 0 to 4176
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   SEX        4177 non-null   int64
#  1   LENGTH     4177 non-null   float64
#  2   DIAMETER   4177 non-null   float64
#  3   HEIGHT     4177 non-null   float64
#  4   FULL_W     4177 non-null   float64
#  5   SHUCKED_W  4177 non-null   float64
#  6   VISERAL_W  4177 non-null   float64
#  7   SHELL_W    4177 non-null   float64
#  8   RINGS      4177 non-null   int64
# dtypes: float64(7), int64(2)
# memory usage: 293.8 KB

# %%
data.describe()
# Out:
#             LENGTH     DIAMETER       HEIGHT       FULL_W    SHUCKED_W  \
# count  4177.000000  4177.000000  4177.000000  4177.000000  4177.000000
# mean      0.523992     0.407881     0.139516     0.828742     0.359367
# std       0.120093     0.099240     0.041827     0.490389     0.221963
# min       0.075000     0.055000     0.000000     0.002000     0.001000
# 25%       0.450000     0.350000     0.115000     0.441500     0.186000
# 50%       0.545000     0.425000     0.140000     0.799500     0.336000
# 75%       0.615000     0.480000     0.165000     1.153000     0.502000
# max       0.815000     0.650000     1.130000     2.825500     1.488000
#
#          VISERAL_W      SHELL_W        RINGS
# count  4177.000000  4177.000000  4177.000000
# mean      0.180594     0.238831     9.933684
# std       0.109614     0.139203     3.224169
# min       0.000500     0.001500     1.000000
# 25%       0.093500     0.130000     8.000000
# 50%       0.171000     0.234000     9.000000
# ...

# %% [markdown]
# Visualizacion de datos para encontrar las relaciones

# %%
import seaborn as sns

sns.pairplot(data)

# %%
x1 = data['SEX']
x2 = data['LENGTH']
x3 = data['DIAMETER']
x4 = data['HEIGHT']
x5 = data['FULL_W']
x6 = data['SHUCKED_W']
x7 = data['VISERAL_W']
x8 = data['SHELL_W']

y = data['RINGS']

x2.corr(x3)
# Out:
# 0.986811584602493

# %% [markdown]
# Limpieza de datos

# %% [markdown]
# Seleccionar y entreanar los modelos de aprendizaje

# %% [markdown]
# Ajustar los parametros del modelo
